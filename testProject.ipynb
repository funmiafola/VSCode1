# %% [markdown]
# How to gennerate the Dataset

# %%
import pandas as pd
boe_rate = pd.read_csv("Bank_of_England_Base_Rate.csv")
#print(boe_rate.head())

# %%
import pandas as pd
import numpy as np

print(pd.__version__)   # Shows Pandas version
print(np.__version__)   # Shows NumPy version
print("pandas and NumPy imported successfully.")
# Out:
# 2.3.3
# 2.3.5
# pandas and NumPy imported successfully.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

print("All libraries installed and ready!")
# Out:
# All libraries installed and ready!

# %%
import sys
print(sys.executable)
print
# Out:
# \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Scripts\python.exe
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
import pandas as pd

boe_rate = pd.read_csv(r"\\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\Bank_of_England_Base_Rate.csv")
print(boe_rate.head())
# Out:
#         Date  \
# 0  30-Nov-25
# 1  31-Oct-25
# 2  30-Sep-25
# 3  31-Aug-25
# 4  31-Jul-25
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICQ  \
# 0                                               3.91
# 1                                               4.03
# 2                                               4.03
# 3                                               3.93
# 4                                               4.02
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [c] [a]             IUMBV34  \
# 0                                               4.06
# 1                                               4.20
# 2                                               4.19
# 3                                               4.10
# 4                                               4.21
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (85% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICR  \
# 0                                               4.23
# 1                                               4.30
# 2                                               4.32
# 3                                               4.21
# 4                                               4.28
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (90% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [c] [d] [a]             IUMB482  \
# 0                                               4.49
# 1                                               4.57
# 2                                               4.58
# 3                                               4.55
# 4                                               4.62
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUM2WTL  \
# 0                                               4.91
# 1                                               5.00
# 2                                               5.03
# 3                                               5.00
# 4                                               5.05
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 3 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV37  \
# 0                                               4.02
# 1                                               4.19
# 2                                               4.18
# 3                                               4.10
# 4                                               4.18
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV42  \
# 0                                               4.07
# 1                                               4.17
# 2                                               4.16
# 3                                               4.11
# 4                                               4.15
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUM5WTL  \
# 0                                               4.82
# 1                                               4.89
# 2                                               4.90
# 3                                               4.86
# 4                                               4.88
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 10 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUMBV45  \
# 0                                               4.52
# 1                                               4.57
# 2                                               4.54
# 3                                               4.46
# 4                                               4.47
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling overdrafts to households (in percent) not seasonally adjusted              [k] [a]             IUMODTL  \
# 0                                              34.50
# 1                                              34.50
# 2                                              34.53
# 3                                              34.55
# 4                                              34.57
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VJ  \
# 0                                               2.20
# 1                                               2.23
# 2                                               2.26
# 3                                               2.27
# 4                                               2.34
#
#   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VK  \
# 0                                               2.09
# 1                                               2.11
# 2                                               2.14
# 3                                               2.19
# 4                                               2.24
#
#   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VL  \
# 0                                               1.87
# 1                                               1.89
# 2                                               2.04
# 3                                               1.87
# 4                                               1.75
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VM  \
# 0                                               1.85
# 1                                               1.86
# 2                                               2.03
# 3                                               1.86
# 4                                               1.74
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VN  \
# 0                                               4.02
# 1                                               4.03
# 2                                               3.97
# 3                                               3.94
# 4                                               3.97
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasona              [a]             IUMZID2  \
# 0                                               3.80
# 1                                               3.82
# 2                                               3.79
# 3                                               3.82
# 4                                               3.82
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [b] [l] [d] [a]             IUMWTFA  \
# 0                                               3.75
# 1                                               3.79
# 2                                               3.79
# 3                                               3.80
# 4                                               3.86
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally              [d] [a]             IUMB6RH  \
# 0                                               3.75
# 1                                               3.77
# 2                                               3.76
# 3                                               3.76
# 4                                               3.78
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling three year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6RI
# 0                                               3.81
# 1                                               3.83
# 2                                               3.83
# 3                                               3.83
# 4                                               3.82
#
# [5 rows x 29 columns]

# %%
num_columns = len(boe_rate.columns)
print("Number of columns:", num_columns)
# Out:
# Number of columns: 29

# %%
print(boe_rate.shape)
# Out:
# (83, 29)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,6))
sns.lineplot(data=boe_rate, x='Date', y='Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted')
plt.title("UK 2-Year 60% LTV Mortgage Interest Rate Over Time")
plt.xlabel("Date")
plt.ylabel("Interest Rate (%)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 import matplotlib.pyplot as plt
#       2 plt.figure(figsize=(12,6))
# ----> 3 sns.lineplot(data=boe_rate, x='Date', y='Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted')
#       4 plt.title("UK 2-Year 60% LTV Mortgage Interest Rate Over Time")
#       5 plt.xlabel("Date")
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
#     486         data=data,
#     487         variables=dict(
#     488             x=x, y=y, hue=hue, size=size, style=style, units=units, weight=weights
#     489         ),
#     490         estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     491         sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     492         legend=legend,
#     493     )
#     495     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     496     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\relational.py:216, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     202 def __init__(
#     203     self, *,
#     204     data=None, variables={},
#    (...)    210     # the kind of plot to draw, but for the time being we need to set
#     211     # this information so the SizeMapping can use it
#     212     self._default_size_range = (
#     213         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     214     )
# --> 216     super().__init__(data=data, variables=variables)
#     218     self.estimator = estimator
#     219     self.errorbar = errorbar
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted` for `y`. An entry with this name does not appear in `data`.

# %%
import sys
print(sys.executable)
# Out:
# \\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Scripts\python.exe

# %%
!\\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\.venv\Scripts\python.exe -m pip install pandas numpy matplotlib seaborn requests
# Out:
# Requirement already satisfied: pandas in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (2.3.5)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (from pandas) (2025.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.0-cp312-cp312-win_amd64.whl.metadata (115 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Using cached urllib3-2.6.1-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: six>=1.5 in \\talktalk\redirectedfolders\f.afolabi\documents\vscode1\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------- ----------- 5.8/8.1 MB 32.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 29.6 MB/s  0:00:00
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp312-cp312-win_amd64.whl (107 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.6.1-py3-none-any.whl (131 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.0-cp312-cp312-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp312-cp312-win_amd64.whl (73 kB)
# Using cached pillow-12.0.0-cp312-cp312-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Installing collected packages: urllib3, pyparsing, pillow, kiwisolver, idna, fonttools, cycler, contourpy, charset_normalizer, certifi, requests, matplotlib, seaborn
#
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    ----------------------------------------  0/13 [urllib3]
#    --- ------------------------------------  1/13 [pyparsing]
#    --- ------------------------------------  1/13 [pyparsing]
#    --- ------------------------------------  1/13 [pyparsing]
#    --- ------------------------------------  1/13 [pyparsing]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    ------ ---------------------------------  2/13 [pillow]
#    --------- ------------------------------  3/13 [kiwisolver]
#    ------------ ---------------------------  4/13 [idna]
#    ------------ ---------------------------  4/13 [idna]
#    ------------ ---------------------------  4/13 [idna]
#    ------------ ---------------------------  4/13 [idna]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    --------------- ------------------------  5/13 [fonttools]
#    ------------------ ---------------------  6/13 [cycler]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    --------------------- ------------------  7/13 [contourpy]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    ------------------------ ---------------  8/13 [charset_normalizer]
#    --------------------------- ------------  9/13 [certifi]
#    --------------------------- ------------  9/13 [certifi]
#    --------------------------- ------------  9/13 [certifi]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    ------------------------------ --------- 10/13 [requests]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    --------------------------------- ------ 11/13 [matplotlib]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ------------------------------------ --- 12/13 [seaborn]
#    ---------------------------------------- 13/13 [seaborn]
#
# Successfully installed certifi charset_normalizer contourpy cycler fonttools idna kiwisolver matplotlib pillow pyparsing requests seaborn urllib3

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

print("All libraries are ready!")
# Out:
# All libraries are ready!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load your CSV
boe_rate = pd.read_csv("Bank_of_England_Base_Rate.csv")

# Step 2: Inspect the data
print(boe_rate.head())
print(boe_rate.info())
# Out:
#         Date  \
# 0  30-Nov-25
# 1  31-Oct-25
# 2  30-Sep-25
# 3  31-Aug-25
# 4  31-Jul-25
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICQ  \
# 0                                               3.91
# 1                                               4.03
# 2                                               4.03
# 3                                               3.93
# 4                                               4.02
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [c] [a]             IUMBV34  \
# 0                                               4.06
# 1                                               4.20
# 2                                               4.19
# 3                                               4.10
# 4                                               4.21
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (85% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICR  \
# 0                                               4.23
# 1                                               4.30
# 2                                               4.32
# 3                                               4.21
# 4                                               4.28
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (90% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [c] [d] [a]             IUMB482  \
# 0                                               4.49
# 1                                               4.57
# 2                                               4.58
# 3                                               4.55
# 4                                               4.62
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUM2WTL  \
# 0                                               4.91
# 1                                               5.00
# 2                                               5.03
# 3                                               5.00
# 4                                               5.05
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 3 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV37  \
# 0                                               4.02
# 1                                               4.19
# 2                                               4.18
# 3                                               4.10
# 4                                               4.18
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV42  \
# 0                                               4.07
# 1                                               4.17
# 2                                               4.16
# 3                                               4.11
# 4                                               4.15
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUM5WTL  \
# 0                                               4.82
# 1                                               4.89
# 2                                               4.90
# 3                                               4.86
# 4                                               4.88
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 10 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUMBV45  \
# 0                                               4.52
# 1                                               4.57
# 2                                               4.54
# 3                                               4.46
# 4                                               4.47
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling overdrafts to households (in percent) not seasonally adjusted              [k] [a]             IUMODTL  \
# 0                                              34.50
# 1                                              34.50
# 2                                              34.53
# 3                                              34.55
# 4                                              34.57
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VJ  \
# 0                                               2.20
# 1                                               2.23
# 2                                               2.26
# 3                                               2.27
# 4                                               2.34
#
#   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VK  \
# 0                                               2.09
# 1                                               2.11
# 2                                               2.14
# 3                                               2.19
# 4                                               2.24
#
#   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VL  \
# 0                                               1.87
# 1                                               1.89
# 2                                               2.04
# 3                                               1.87
# 4                                               1.75
#
#    Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VM  \
# 0                                               1.85
# 1                                               1.86
# 2                                               2.03
# 3                                               1.86
# 4                                               1.74
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VN  \
# 0                                               4.02
# 1                                               4.03
# 2                                               3.97
# 3                                               3.94
# 4                                               3.97
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasona              [a]             IUMZID2  \
# 0                                               3.80
# 1                                               3.82
# 2                                               3.79
# 3                                               3.82
# 4                                               3.82
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [b] [l] [d] [a]             IUMWTFA  \
# 0                                               3.75
# 1                                               3.79
# 2                                               3.79
# 3                                               3.80
# 4                                               3.86
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally              [d] [a]             IUMB6RH  \
# 0                                               3.75
# 1                                               3.77
# 2                                               3.76
# 3                                               3.76
# 4                                               3.78
#
#    Monthly interest rate of UK MFIs (excl. Central Bank) sterling three year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6RI
# 0                                               3.81
# 1                                               3.83
# 2                                               3.83
# 3                                               3.83
# 4                                               3.82
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83 entries, 0 to 82
# Data columns (total 29 columns):
#  #   Column                                                                                                                                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                       --------------  -----
#  0   Date                                                                                                                                                                                                                                         83 non-null     object
#  1   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (60% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICQ                       83 non-null     float64
#  2   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [c] [a]             IUMBV34               83 non-null     float64
#  3   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (85% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZICR                       83 non-null     float64
#  4   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (90% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [c] [d] [a]             IUMB482               83 non-null     float64
#  5   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUM2WTL                   83 non-null     float64
#  6   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 3 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV37               83 non-null     float64
#  7   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUMBV42               83 non-null     float64
#  8   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 5 year (95% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [d] [a]             IUM5WTL               83 non-null     float64
#  9   Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 10 year (75% LTV) fixed rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUMBV45                  83 non-null     float64
#  10  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (75% LTV) variable rate mortgage to households (in percent) not seasonally adjusted              [b] [e] [a]             IUMBV48            83 non-null     float64
#  11  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (90% LTV) variable rate mortgage to households (in percent) not seasonally adjusted              [e] [a] [f]             IUMB479            83 non-null     float64
#  12  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (95% LTV) variable rate mortgage to households (in percent) not seasonally adjusted              [g] [h] [a]             IUM2WDT            83 non-null     object
#  13  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling Lifetime Tracker mortgage to households (in percent) not seasonally adjusted              [b] [i] [d] [a]             IUMBV24                      83 non-null     object
#  14  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling revert-to-rate mortgage to households (in percent) not seasonally adjusted              [b] [a]             IUMTLMV                                83 non-null     float64
#  15  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling 2 year (75% LTV) buy to let fixed rate mortgage to households (in percent) not seasonally adjusted              [a]             IUMZID4            83 non-null     float64
#  16  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling personal loan, £5K to households (in percent) not seasonally adjusted              [j] [a]             IUMBX67                                     83 non-null     float64
#  17  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling personal loan, £10K to households (in percent) not seasonally adjusted              [b] [j] [a]             IUMHPTL                                83 non-null     float64
#  18  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling representative credit card lending to households (in percent) not seasonally adjusted              [b] [a]             IUMCCTL                     83 non-null     float64
#  19  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling overdrafts to households (in percent) not seasonally adjusted              [k] [a]             IUMODTL                                             83 non-null     float64
#  20  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VJ  83 non-null     float64
#  21  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling instant access deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6VK  83 non-null     float64
#  22  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VL    83 non-null     float64
#  23  Monthly interest rate of UK monetary financial institutions (excl. Central Bank) sterling cash ISA deposits excluding unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VM    83 non-null     float64
#  24  Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [d] [a]             IUMB6VN           83 non-null     float64
#  25  Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate cash ISA deposits including unconditional bonuses from households (in percent) not seasona              [a]             IUMZID2                           83 non-null     float64
#  26  Monthly interest rate of UK MFIs (excl. Central Bank) sterling one year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [b] [l] [d] [a]             IUMWTFA       83 non-null     float64
#  27  Monthly interest rate of UK MFIs (excl. Central Bank) sterling two year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally              [d] [a]             IUMB6RH                        83 non-null     float64
#  28  Monthly interest rate of UK MFIs (excl. Central Bank) sterling three year fixed rate bond deposits including unconditional bonuses from households (in percent) not seasonally adjusted              [a]             IUMB6RI                 83 non-null     float64
# dtypes: float64(26), object(3)
# memory usage: 18.9+ KB
# None

# %%
print(f"Number of columns: {boe_rate.shape[1]}")
# Out:
# Number of columns: 29

# %%
boe_rate = boe_rate.rename(columns={
    boe_rate.columns[1]: "2yr_60_LTV",
    boe_rate.columns[2]: "2yr_75_LTV",
    boe_rate.columns[3]: "2yr_85_LTV",
    boe_rate.columns[4]: "2yr_90_LTV",
    boe_rate.columns[5]: "2yr_95_LTV",
})

# %%
boe_rate['Date'] = pd.to_datetime(boe_rate['Date'], dayfirst=True)

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=boe_rate, x='Date', y='2yr_60_LTV', label='2yr 60% LTV')
sns.lineplot(data=boe_rate, x='Date', y='2yr_75_LTV', label='2yr 75% LTV')
sns.lineplot(data=boe_rate, x='Date', y='2yr_85_LTV', label='2yr 85% LTV')
plt.title("UK 2-Year Fixed Rate Mortgages")
plt.xlabel("Date")
plt.ylabel("Interest Rate (%)")
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

fig, axes = plt.subplots(figsize=(8,8))

sns.scatterplot(data=boe_rate, x='2yr_60_LTV', y='2yr_75_LTV', hue='2yr_85_LTV')   # Seaborn code to draw a scatter plot
plt.title("Seaborn Plot!!!")
plt.xlabel('X-Axis: 2yr_60_LTV')
plt.legend(loc='upper left', title='Legend', frameon=False)
plt.show()

# %%
sns.pairplot(data=boe_rate )
plt.show()

# %%
import pandas as pd

cpi = pd.read_csv(r"\\talktalk\redirectedfolders\F.Afolabi\Documents\VSCode1\inflation.csv")
cpi.columns = ['Date', 'CPI_Inflation']
print(cpi.head())
cpi.info()
# Out:
#    Date  CPI_Inflation
# 0  1996           68.8
# 1  1997           70.1
# 2  1998           71.2
# 3  1999           72.1
# 4  2000           72.7
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1280 non-null   object
#  1   CPI_Inflation  634 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 20.1+ KB

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1280 entries, 0 to 1279
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           1280 non-null   object
#  1   CPI_Inflation  634 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 20.1+ KB

# %%
print(f"Number of columns: {cpi.shape[1]}")
# Out:
# Number of columns: 2

# %%
cpi['Date'] = cpi['Date'].astype(str)
cpi['Date'] = cpi['Date'].str.replace(' Q', '-Q')
cpi['Date'] = pd.PeriodIndex(cpi['Date'], freq='Q').to_timestamp()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests




plt.figure(figsize=(12,6))
sns.lineplot(data=cpi, x='Date', y='CPI_Inflation', label='inflation')
plt.title("UK CPI Inflation Over Time")
plt.xlabel("Date")
plt.ylabel("CPI_Inflation")
plt.legend()
plt.show()
